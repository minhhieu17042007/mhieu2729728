# %%
a, b , c = map(int(input()).split())
if a + b > c or a + c > b or a + c > b : 
    print ('Đây là 3 cạnh của một tam giác ')
    p = a+ b + c 
    dien_tich = (p(p -a ) +p(p- b) + p(p-c) ) ** 0.5
    print ()
